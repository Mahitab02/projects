# %% [markdown]
# <a href="https://colab.research.google.com/github/Mahitab02/projects/blob/main/visualization1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import plotly.graph_objs as go
import plotly as py
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
from plotly.offline import init_notebook_mode, iplot, plot

# %%
data = pd.read_csv('cwurData.csv')
data.head()
# Out:
#    world_rank                            institution         country  \
# 0           1                     Harvard University             USA
# 1           2  Massachusetts Institute of Technology             USA
# 2           3                    Stanford University             USA
# 3           4                University of Cambridge  United Kingdom
# 4           5     California Institute of Technology             USA
#
#    national_rank  quality_of_education  alumni_employment quality_of_faculty  \
# 0              1                     7                  9                  1
# 1              2                     9                 17                  3
# 2              3                    17                 11                  5
# 3              1                    10                 24                  4
# 4              4                     2                 29                  7
#
#    publications  influence  citations  broad_impact  patents   score  year
# ...

# %%
df = pd.read_csv('timesData.csv')
df.head()
# Out:
#   world_rank                        university_name                   country  \
# 0          1                     Harvard University  United States of America
# 1          2     California Institute of Technology  United States of America
# 2          3  Massachusetts Institute of Technology  United States of America
# 3          4                    Stanford University  United States of America
# 4          5                   Princeton University  United States of America
#
#    teaching international  research  citations income total_score  \
# 0      99.7          72.4      98.7       98.8   34.5        96.1
# 1      97.7          54.6      98.0       99.9   83.7        96.0
# 2      97.8          82.3      91.4       99.9   87.5        95.6
# 3      98.3          29.5      98.1       99.2   64.3        94.3
# 4      90.9          70.3      95.4       99.9      -        94.2
#
#   num_students  student_staff_ratio international_students female_male_ratio  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   world_rank            2200 non-null   int64
#  1   institution           2200 non-null   object
#  2   country               2200 non-null   object
#  3   national_rank         2200 non-null   int64
#  4   quality_of_education  2200 non-null   int64
#  5   alumni_employment     2200 non-null   int64
#  6   quality_of_faculty    2200 non-null   object
#  7   publications          2200 non-null   int64
#  8   influence             2200 non-null   int64
#  9   citations             2200 non-null   int64
#  10  broad_impact          2000 non-null   float64
#  11  patents               2200 non-null   int64
#  12  score                 2200 non-null   float64
#  13  year                  2200 non-null   int64
# dtypes: float64(2), int64(9), object(3)
# ...

# %%
data.isnull().sum()
# Out:
# world_rank                0
# institution               0
# country                   0
# national_rank             0
# quality_of_education      0
# alumni_employment         0
# quality_of_faculty        0
# publications              0
# influence                 0
# citations                 0
# broad_impact            200
# patents                   0
# score                     0
# year                      0
# dtype: int64

# %%
data.drop('broad_impact', inplace=True, axis=1)
data.head()
# Out:
#    world_rank                            institution         country  \
# 0           1                     Harvard University             USA
# 1           2  Massachusetts Institute of Technology             USA
# 2           3                    Stanford University             USA
# 3           4                University of Cambridge  United Kingdom
# 4           5     California Institute of Technology             USA
#
#    national_rank  quality_of_education  alumni_employment quality_of_faculty  \
# 0              1                     7                  9                  1
# 1              2                     9                 17                  3
# 2              3                    17                 11                  5
# 3              1                    10                 24                  4
# 4              4                     2                 29                  7
#
#    publications  influence  citations  patents   score  year
# ...

# %%
data.isnull().sum()
# Out:
# world_rank              0
# institution             0
# country                 0
# national_rank           0
# quality_of_education    0
# alumni_employment       0
# quality_of_faculty      0
# publications            0
# influence               0
# citations               0
# patents                 0
# score                   0
# year                    0
# dtype: int64

# %%
data.corr()
# Out:
#                       world_rank  national_rank  quality_of_education  \
# world_rank              1.000000       0.238553              0.676166
# national_rank           0.238553       1.000000              0.211975
# quality_of_education    0.676166       0.211975              1.000000
# alumni_employment       0.668529       0.135342              0.606421
# publications            0.923037       0.326857              0.624657
# influence               0.895871       0.161086              0.645641
# citations               0.856573       0.186797              0.630455
# patents                 0.698214       0.159440              0.528120
# score                  -0.549098      -0.199756             -0.600541
# year                    0.320844       0.102951              0.427732
#
#                       alumni_employment  publications  influence  citations  \
# world_rank                     0.668529      0.923037   0.895871   0.856573
# ...

# %%
data['score'].describe()
# Out:
# count    2200.000000
# mean       47.798395
# std         7.760806
# min        43.360000
# 25%        44.460000
# 50%        45.100000
# 75%        47.545000
# max       100.000000
# Name: score, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2603 entries, 0 to 2602
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   world_rank              2603 non-null   object
#  1   university_name         2603 non-null   object
#  2   country                 2603 non-null   object
#  3   teaching                2603 non-null   float64
#  4   international           2603 non-null   object
#  5   research                2603 non-null   float64
#  6   citations               2603 non-null   float64
#  7   income                  2603 non-null   object
#  8   total_score             2603 non-null   object
#  9   num_students            2544 non-null   object
#  10  student_staff_ratio     2544 non-null   float64
#  11  international_students  2536 non-null   object
#  12  female_male_ratio       2370 non-null   object
#  13  year                    2603 non-null   int64
# ...

# %%
df.isnull().sum()
# Out:
# world_rank                  0
# university_name             0
# country                     0
# teaching                    0
# international               0
# research                    0
# citations                   0
# income                      0
# total_score                 0
# num_students               59
# student_staff_ratio        59
# international_students     67
# female_male_ratio         233
# year                        0
# dtype: int64

# %%
df.corr()
# Out:
#                      teaching  research  citations  student_staff_ratio  \
# teaching             1.000000  0.913120   0.503867            -0.282630
# research             0.913120  1.000000   0.525264            -0.198841
# citations            0.503867  0.525264   1.000000            -0.137737
# student_staff_ratio -0.282630 -0.198841  -0.137737             1.000000
# year                -0.278108 -0.274451  -0.173544             0.060728
#
#                          year
# teaching            -0.278108
# research            -0.274451
# citations           -0.173544
# student_staff_ratio  0.060728
# year                 1.000000

# %%
df['total_score'].describe()
# Out:
# count     2603
# unique     415
# top          -
# freq      1402
# Name: total_score, dtype: object

# %%
df['income'].describe()
# Out:
# count     2603
# unique     613
# top          -
# freq       218
# Name: income, dtype: object

# %%
fig1 = px.bar(data, x="institution", y="country", title="universities vs countries  ", orientation= 'h')
fig1.show()
# Out:
# <div>                            <div id="f9095ab5-aaff-43c2-a7a8-9a2d7e3d6ff7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f9095ab5-aaff-43c2-a7a8-9a2d7e3d6ff7")) {                    Plotly.newPlot(                        "f9095ab5-aaff-43c2-a7a8-9a2d7e3d6ff7",                        [{"alignmentgroup":"True","hovertemplate":"institution=%{x}<br>country=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":["Harvard University","Massachusetts Institute of Technology","Stanford University","University of Cambridge","California Institute of Technology","Princeton University","University of Oxford","Yale University","Colum
# ...

# %%
uni_df = data['institution'].value_counts()

fig, ax = plt.subplots(figsize=(10,10), dpi=150)

sns.countplot(data=data, y='country', order=data.country.value_counts().index);
plt.xlabel('Number of universities', fontsize=12, color = '#6B8E23')
plt.ylabel('Country', fontsize=12, color = '#6B8E23')
plt.title("Distribution of universities across countries", fontsize=14, color = '#6B8E23');

# %%
from wordcloud import WordCloud
# data prepararion
x2012 =data.country[data.year == 2012]
plt.subplots(figsize=(8,8))
wordcloud = WordCloud(
                          background_color='white',
                          width=512,
                          height=384
                         ).generate(" ".join(x2012))
plt.imshow(wordcloud)
plt.axis('off')


plt.show()

# %%
fig2 = px.pie(data, values='year', names='patents',color= "country")
fig2.show()
# Out:
# <div>                            <div id="89076797-b0c2-4fb0-bcbb-3bdb497d3b4f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("89076797-b0c2-4fb0-bcbb-3bdb497d3b4f")) {                    Plotly.newPlot(                        "89076797-b0c2-4fb0-bcbb-3bdb497d3b4f",                        [{"customdata":[["USA"],["USA"],["USA"],["United Kingdom"],["USA"],["USA"],["United Kingdom"],["USA"],["USA"],["USA"],["USA"],["USA"],["USA"],["Japan"],["USA"],["Switzerland"],["Japan"],["palastine"],["USA"],["USA"],["USA"],["palastine"],["USA"],["USA"],["USA"],["USA"],["USA"],["United Kingdom"],["USA"],["USA"],["United Kingdom"],["Japan"],["USA"],["USA"],["Canada"],["USA"],["USA"],["USA"],["USA"],["USA"],["Canada"],["USA"],["USA"],["USA"],["USA"],["USA"],["USA"],
# ...

# %%
fig = px.scatter_3d(data, x="world_rank", y="citations",z='patents',animation_frame="country" ,color='world_rank')
fig.show()
# Out:
# <div>                            <div id="5b2ef3fd-2d2e-4b6b-bb37-fcb682969f22" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5b2ef3fd-2d2e-4b6b-bb37-fcb682969f22")) {                    Plotly.newPlot(                        "5b2ef3fd-2d2e-4b6b-bb37-fcb682969f22",                        [{"hovertemplate":"country=USA<br>world_rank=%{marker.color}<br>citations=%{y}<br>patents=%{z}<extra></extra>","legendgroup":"","marker":{"color":[1,2,3,5,6,8,9,10,11,12,13,15,19,20,21,23,24,25,26,27,29,30,33,34,36,37,38,39,40,42,43,44,45,46,47,49,50,52,53,55,57,58,59,62,64,66,68,71,72,73,78,80,81,84,86,87,95,96,1,2,4,6,7,8,9,10,11,12,13,16,17,19,20,22,23,24,25,26,28,31,32,34,37,38,39,41,42,43,44,46,49,50,51,52,53,54,55,59,61,63,65,69,71,73,76,77,78,80,82,85,88,89
# ...

# %%
df =df.iloc[:100,:]
trace1 = go.Scatter(
                    x = df.world_rank,                       
                    y = df.citations,
                    mode = "lines",
                    name = "citations",
                    marker = dict(color = 'rgba(30, 144, 255, 0.8)'),
                    text= df.university_name)
# Creating trace2
trace2 = go.Scatter(
                    x = df.world_rank,
                    y = df.teaching,
                    mode = "lines+markers",
                    name = "teaching",
                    marker = dict(color = 'rgba(255, 255,0, 0.8)'),    
                    text= df.university_name)                        
data = [trace1, trace2]
layout = dict(title = 'Citation and Teaching vs World Rank of Top 100 Universities',
              xaxis= dict(title= 'World Rank',ticklen= 5,zeroline= False)      
             )
fig = dict(data = data, layout = layout)
iplot(fig)
# Out:
# <div>                            <div id="44fff18c-40d1-475f-b1ba-2db82bc47db0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("44fff18c-40d1-475f-b1ba-2db82bc47db0")) {                    Plotly.newPlot(                        "44fff18c-40d1-475f-b1ba-2db82bc47db0",                        [{"marker":{"color":"rgba(30, 144, 255, 0.8)"},"mode":"lines","name":"citations","text":["Harvard University","California Institute of Technology","Massachusetts Institute of Technology","Stanford University","Princeton University","University of Cambridge","University of Oxford","University of California, Berkeley","Imperial College London","Yale University","University of California, Los Angeles","University of Chicago","Johns Hopkins University","Cornell Univer
# ...

# %%
fig = px.scatter(df, x="international", y="research", animation_frame="country", 
           size="citations", color="university_name", hover_name="country",
           )

fig["layout"].pop("updatemenus") # optional, drop animation buttons
fig.show()
# Out:
# <div>                            <div id="402980d2-1e9a-4840-90b9-65731621ad7c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("402980d2-1e9a-4840-90b9-65731621ad7c")) {                    Plotly.newPlot(                        "402980d2-1e9a-4840-90b9-65731621ad7c",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>university_name=Harvard University<br>country=United States of America<br>international=%{x}<br>research=%{y}<br>citations=%{marker.size}<extra></extra>","hovertext":["United States of America"],"legendgroup":"Harvard University","marker":{"color":"#636efa","size":[98.8],"sizemode":"area","sizeref":0.24975000000000003,"symbol":"circle"},"mode":"markers","name":"Harvard University","orientation":"v","showlegend":true,"x
# ...

# %%
from matplotlib.colors import ListedColormap
import geopandas as gpd
import missingno as msno

# %%
long_palette = ["#FA6E4F", "#F2CF59", "#FB8E7E", "#C5D7C0", "#8EC9BB", "#F8CA9D", '#F69EAF', '#8F8CBC', '#7C5396', '#EA6382', '#6BEAF3', '#5A9DE2', '#DDAD64', '#EA876B', '#B98174', '#357866', '#625586', '#647B99']
custom_palette1 = sns.color_palette(long_palette)

short_palette = ["#FA6E4F", "#F2CF59", "#FB8E7E", "#C5D7C0", "#8EC9BB", "#F8CA9D"]
custom_palette2 = sns.color_palette(short_palette)
watermelon_colors = ['#84e3c8', '#a8e6cf', '#dcedc1', '#ffd3b6', '#ffaaa5', '#ff8b94', '#ff7480']
custom_palette3 = sns.color_palette(watermelon_colors)

# %%
custom_palette2 = sns.color_palette(short_palette)
cmap = ListedColormap(custom_palette3, name='cmap1')
msno.heatmap(df, cmap=cmap, figsize=(13, 6), fontsize=14);

# %%
indices = pd.read_excel('D://indices.xlsx')

# %%
np.random.seed(1)
x0 = indices[1] #patents
y0 = indices[2] #world_rank
x1 = indices[3] #citations
y1 = indices[4] #influence
x2 = indices[5] #quality_of_education
y2 = indices[6] #score


# Create figure
fig1 = go.Figure()

# Add traces
fig1.add_trace(go.Scatter(x=x0,y=y0,mode="markers",marker=dict(color="DarkOrange")))
fig1.add_trace(go.Scatter( x=x1,y=y1,mode="markers",marker=dict(color="Crimson")))
fig1.add_trace(go.Scatter(x=x2,y=y2,mode="markers", marker=dict(color="RebeccaPurple")))

# Add buttons that add shapes
cluster0 = [dict(type="circle",xref="x", yref="y",x0=min(x0), y0=min(y0), x1=max(x0), y1=max(y0),line=dict(color="DarkOrange"))]
cluster1 = [dict(type="circle", xref="x", yref="y",x0=min(x1), y0=min(y1),x1=max(x1), y1=max(y1),line=dict(color="Crimson"))]
cluster2 = [dict(type="circle",xref="x", yref="y",x0=min(x2), y0=min(y2),x1=max(x2), y1=max(y2), line=dict(color="RebeccaPurple"))]
fig1.update_layout(updatemenus=[dict(buttons=list([ dict(label="None", method="relayout", args=["shapes", []]),dict(label="Cluster 0",
method="relayout", args=["shapes", cluster0]),dict(label="Cluster 1", method="relayout",args=["shapes", cluster1]),dict(label="Cluster 2",
method="relayout",args=["shapes", cluster2]),
dict(label="All", method="relayout",args=["shapes", cluster0 + cluster1 + cluster2])]),)])

# Update remaining layout properties
fig1.update_layout(title_text="Highlight Clusters",showlegend=False,)
fig1.show()
# Out:
# <div>                            <div id="e25d9a3c-991d-41aa-a539-5fde24a01bf4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e25d9a3c-991d-41aa-a539-5fde24a01bf4")) {                    Plotly.newPlot(                        "e25d9a3c-991d-41aa-a539-5fde24a01bf4",                        [{"marker":{"color":"DarkOrange"},"mode":"markers","x":[5,1,15,50,18,101,26,66,5,16,101,10,9,3,7,34,23,29,13,22,101,28,62,33,21,44,20,41,101,57,86,11,35,8,101,29,14,12,101,101,101,19,101,23,32,101,65,101,84,27,51,54,62,101,2,35,101,92,101,101,101,101,101,99,101,101,101,101,74,101,61,85,101,46,4,101,101,101,29,49,46,101,101,86,101,101,40,101,101,101,101,46,101,69,101,100,92,101,101,101,7,11,15,1,39,10,19,101,101,42,17,14,7,5,13,12,2,60,51,22,24,63,30,67,24,20,48,30
# ...
